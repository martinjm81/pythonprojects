# %% [markdown]
# <a href="https://colab.research.google.com/github/martinjm81/pythonprojects/blob/Econometrics/pgd_aleatorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=19
print(A)

# %%
import numpy as np

np.random.seed(2)

dias = 30

IEL = np.array(np.random.uniform(0,100,dias) )
IEL
import matplotlib.pyplot as plt

figure, grafico = plt.subplots(figsize = (10,6))
grafico = plt.plot(IEL)
grafico = plt.ylabel('Acciones de IEL')
